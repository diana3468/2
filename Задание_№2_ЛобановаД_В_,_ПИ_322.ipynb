# %% [markdown]
# ###  Формула нормального распределения: $\frac{1}{\sigma\sqrt{2\pi}}
#    \exp\left(-\frac{(x-\mu)^2}{2\sigma^2}\right)$
#
# ### <u> Греческий алфавит:<u>
#
# | Прописные  |Строчные                   |Название    |
# |:--------:  |:---------:                |:----------:|
# | A          | $\alpha$                  |      альфа |
# |B           |$\beta$                    |бета        |
# |$\Gamma$    |$\gamma$                   |гамма       |
# | $\Delta$   |$\delta$                   |дельта      |
# |E           |$\epsilon$, $\varepsilon$  |эпсилон     |
# |Z           |$\zeta$                    |дзета       |
# |H           |$\eta$                     |эта         |
# |$\Theta$    |$\theta$, $\vartheta$      |тета        |
# |I           |$\iota$                    |йота        |
# |K           |$\kappa$, $\varkappa$      |каппа       |
# |$\Lambda$   |$\lambda$                  |лямбда      |
# |M           |$\mu$                      |мю          |
# |N           |$\nu$                      |ню          |
# |$\Xi$       |$\xi$                      |кси         |
# |O           |o                          |омикрон     |
# |$\Pi$       |$\pi$                      |пи          |
# |P           |$\rho$, $\varrho$          |ро          |
# |$\Sigma$    |$\sigma$, $\varsigma$      |сигма       |
# |T           |$\tau$                     |тау         |
# |$\Upsilon$  |$\upsilon$                 |ипсилон     |
# |$\Phi$      |$\phi$, $\varphi$          |фи          |
# |X           |$\chi$                     |хи          |
# |$\Psi$      |$\psi$                     |пси         |
# |$\Omega$    |$\omega$                   |омега       |
#
# #заголовок первого уровня
# ##заголовок второго уровня
# ###заголовок третьего уровня
